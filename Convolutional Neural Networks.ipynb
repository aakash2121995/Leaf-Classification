# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.optimizers import SGD
from keras.models import load_model
from keras import backend as K
K.set_image_dim_ordering('tf')

# dimensions of our images.
img_width = 256
img_height = 256

train_data_dir = 'Training Data/'
validation_data_dir = 'Test Data/'
# nb_train_samples = 7102
# nb_validation_samples = 198
# nb_epoch = 5

model = load_model("67 epoch 7 April.h5")

# model = Sequential()
# model.add(Convolution2D(32,2,2, input_shape=(img_width, img_height,3)))
# model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Convolution2D(64,3, 3))
# model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Convolution2D(128, 3, 3))
# model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# # model.add(Convolution2D(256, 3, 3))
# # model.add(Activation('relu'))
# # model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Flatten())
# model.add(Dense(1024))
# model.add(Activation('relu'))
# model.add(Dropout(0.2))
# model.add(Dense(1024))
# model.add(Activation('relu'))
# model.add(Dropout(0.4))
# model.add(Dense(179))
# model.add(Activation('softmax'))

# model.compile(loss='categorical_crossentropy',
#               optimizer=SGD(lr=0.01,momentum=0.6,decay=1e-7),
# metrics=['accuracy'])
# Out:
# Using TensorFlow backend.

# %%
# # this is the augmentation configuration we will use for training
# train_datagen = ImageDataGenerator(
#     rescale=1.0/255,
#     rotation_range=20,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     zoom_range=0.1,
#     horizontal_flip=True,
#     vertical_flip=True
# )

# # # this is the augmentation configuration we will use for testing:
# # # only rescaling
# # train_data_dir = '../Labelled Train Data/'
# test_datagen = ImageDataGenerator(rescale=1.0/255)
# # train_generator = train_datagen.flow_from_directory(
# #         train_data_dir,
# #         target_size=(img_width, img_height),
# #         batch_size=16,
# #         class_mode='categorical')


# validation_generator = test_datagen.flow_from_directory(
#         validation_data_dir,
#         target_size=(img_width, img_height),
#         batch_size=64,
#         class_mode='categorical')

# # model.optimizer.momentum.set_value = 0.7
# # # model.optimizer.lr.set_value = 0.1

# # model.fit_generator(
# #         train_generator,
# #         samples_per_epoch=26494,
# #         nb_epoch=7,
# #         validation_data=validation_generator,
# # nb_val_samples=3311,callbacks=[EarlyStoppingByLossVal(),EarlyStopping(monitor="val_acc")]
# # )

# # model.save("17epoch 7 April.h5")
# # model.optimizer.momentum.set_value = 0.8
# # # model.optimizer.lr.set_value = 0.1

# # train_generator = train_datagen.flow_from_directory(
# #         train_data_dir,
# #         target_size=(img_width, img_height),
# #         batch_size=20,
# #         class_mode='categorical')

# # model.fit_generator(
# #         train_generator,
# #         samples_per_epoch=26494,
# #         nb_epoch=7,
# #         validation_data=validation_generator,
# # nb_val_samples=3311,callbacks=[EarlyStoppingByLossVal(),EarlyStopping(monitor="val_acc")]
# # )

# # model.save("24epoch 7 April.h5")

# # train_generator = train_datagen.flow_from_directory(
# #         train_data_dir,
# #         target_size=(img_width, img_height),
# #         batch_size=24,
# #         class_mode='categorical')

# # model.optimizer.momentum.set_value = 0.9
# # # model.optimizer.lr.set_value = 0.1

# # model.fit_generator(
# #         train_generator,
# #         samples_per_epoch=26494,
# #         nb_epoch=7,
# #         validation_data=validation_generator,
# # nb_val_samples=3311,callbacks=[EarlyStoppingByLossVal(),EarlyStopping(monitor="val_acc")]
# # )

# # model.save("31 epoch 7 April.h5")

# train_generator = train_datagen.flow_from_directory(
#         train_data_dir,
#         target_size=(img_width, img_height),
#         batch_size=128,
#         class_mode='categorical')

# model.optimizer.momentum.set_value = 0.95
# model.optimizer.lr.set_value = 0.

model.fit_generator(
        train_generator,
        samples_per_epoch=26494,
        nb_epoch=30,
        validation_data=validation_generator,
nb_val_samples=3311,callbacks=[EarlyStoppingByLossVal()]
)

# model.save("67 epoch 7 April.h5")
# Out:
# Epoch 1/30
# 26494/26494 [==============================] - 493s - loss: 0.3624 - acc: 0.8740 - val_loss: 0.2733 - val_acc: 0.9024
# Epoch 2/30
# 26494/26494 [==============================] - 467s - loss: 0.3482 - acc: 0.8799 - val_loss: 0.2533 - val_acc: 0.9136
# Epoch 3/30
# 26494/26494 [==============================] - 466s - loss: 0.3582 - acc: 0.8713 - val_loss: 0.2569 - val_acc: 0.9058
# Epoch 4/30
# 26494/26494 [==============================] - 468s - loss: 0.3568 - acc: 0.8756 - val_loss: 0.2420 - val_acc: 0.9106
# Epoch 5/30
# 26494/26494 [==============================] - 472s - loss: 0.3495 - acc: 0.8783 - val_loss: 0.2606 - val_acc: 0.9118
# Epoch 6/30
# 26494/26494 [==============================] - 468s - loss: 0.3425 - acc: 0.8814 - val_loss: 0.2331 - val_acc: 0.9169
# Epoch 7/30
#  6784/26494 [======>.......................] - ETA: 264s - loss: 0.3557 - acc: 0.8749

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback

class EarlyStoppingByLossVal(Callback):
    def __init__(self, monitor='val_loss', value=0.2, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current < self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping THR" % epoch)
            self.model.stop_training = True

# %%
model.save("Best model probably.h5")
import smtplib

# Import the email modules we'll need
from email.mime.text import MIMEText

# Open a plain text file for reading.  For this example, assume that
# the text file contains only ASCII characters.

# Create a text/plain message
from urllib2 import urlopen
my_ip = urlopen('http://ip.42.pl/raw').read()
msg = MIMEText('Link: https://' + my_ip + ':8888')

me = "jupyter@dubaraChla.com"
you = "aakash.srt@gmail.com"
# me == the sender's email address
# you == the recipient's email address
msg['Subject'] = 'Training ho gyi'
msg['From'] = me
msg['To'] = you

# Send the message via our own SMTP server, but don't include the
# envelope header.
s = smtplib.SMTP('localhost')
s.sendmail(me, [you], msg.as_string())
s.quit()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-39-ebd127c67275> in <module>()
#       9
#      10 # Create a text/plain message
# ---> 11 from urllib2 import urlopen
#      12 my_ip = urlopen('http://ip.42.pl/raw').read()
#      13 msg = MIMEText('Link: https://' + my_ip + ':8888')
#
# ImportError: No module named 'urllib2'

# %%
print("hello")
# Out:
# hello

# %%
import smtplib

# Import the email modules we'll need
from email.mime.text import MIMEText

# Open a plain text file for reading.  For this example, assume that
# the text file contains only ASCII characters.

# Create a text/plain message
from urllib2 import urlopen
my_ip = urlopen('http://ip.42.pl/raw').read()
msg = MIMEText('Link: https://' + my_ip + ':8888')

me = "jupyter@dubaraChla.com"
you = "aakash.srt@gmail.com"
# me == the sender's email address
# you == the recipient's email address
msg['Subject'] = 'Training ho gyi'
msg['From'] = me
msg['To'] = you

# Send the message via our own SMTP server, but don't include the
# envelope header.
s = smtplib.SMTP('localhost')
s.sendmail(me, [you], msg.as_string())
s.quit()
